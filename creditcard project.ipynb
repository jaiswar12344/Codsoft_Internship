# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#distribution on transaction & fraudulant transaction
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#checking the class distribution of the traget variable in percentage
print((df.groupby('Class')['Class'].count()/df['Class'].count())*100)
((df.groupby('Class')['Class'].count()/df['Class'].count())*100).plot.pie()
#we can se here there is only one percentage of fraud transaction
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: Class, dtype: float64
# <Axes: ylabel='Class'>

# %%
corr=df.corr()
corr
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %%
#checking correlation using heat map
plt.figure(figsize=(26,20))
sns.heatmap(corr,cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %%
#Drop unnecessary columns



# we will drop Time, as we have derived the Day/Hour/Minutes from the time column 
df.drop("Time", axis= 1, inplace=True) 
#We will keep only derived column hour, as day/minutes might not be very useful

df.drop(['Time_Day', 'Time_Min'], axis=1, inplace=True)

# %%
#dep data forr analysis
normal=df[df.Class ==0]
fraud=df[df.Class ==1]

# %%
print(normal.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
df.groupby('Class').mean()
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# Class
# 0      0.008258 -0.006271  0.012171 -0.007860  0.005453  0.002419  0.009637
# 1     -4.771948  3.623778 -7.033281  4.542029 -3.151225 -1.397737 -5.568731
#
#              V8        V9       V10  ...       V21       V22       V23  \
# Class                                ...
# 0     -0.000987  0.004467  0.009824  ... -0.001235 -0.000024  0.000070
# 1      0.570636 -2.581123 -5.676883  ...  0.713588  0.014049 -0.040308
#
#             V24       V25       V26       V27       V28      Amount  Time_Hour
# Class
# 0      0.000182 -0.000072 -0.000089 -0.000295 -0.000131   88.291022  14.050623
# 1     -0.105130  0.041449  0.051648  0.170575  0.075667  122.211321  11.646341
#
# [2 rows x 30 columns]

# %%
#comp-pare value of both transaction

df.groupby('Class').mean()
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# Class
# 0      0.008258 -0.006271  0.012171 -0.007860  0.005453  0.002419  0.009637
# 1     -4.771948  3.623778 -7.033281  4.542029 -3.151225 -1.397737 -5.568731
#
#              V8        V9       V10  ...       V21       V22       V23  \
# Class                                ...
# 0     -0.000987  0.004467  0.009824  ... -0.001235 -0.000024  0.000070
# 1      0.570636 -2.581123 -5.676883  ...  0.713588  0.014049 -0.040308
#
#             V24       V25       V26       V27       V28      Amount  Time_Hour
# Class
# 0      0.000182 -0.000072 -0.000089 -0.000295 -0.000131   88.291022  14.050623
# 1     -0.105130  0.041449  0.051648  0.170575  0.075667  122.211321  11.646341
#
# [2 rows x 30 columns]

# %%
#under sampling
#build a sample dataset containg similar disribution andd fraud tans
normal_sample=normal.sample(n=492)

# %%
new_dataset=pd.concat([normal_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 264993 -0.412665  0.799263  0.211213  0.337211  0.298819  0.194876  0.173101
# 185295 -1.901385 -1.641704  1.801183 -0.380705  0.753314 -0.819420  0.318177
# 171218 -0.315761  0.479915  0.779429 -1.140265  0.901688  0.639046  0.475414
# 266896  2.012053  0.076522 -1.616732  0.339402  0.381926 -0.583722  0.042644
# 188112 -1.905378  0.767421  2.512406  0.507226 -1.797051  1.187800 -1.236078
#
#               V8        V9       V10  ...       V22       V23       V24  \
# 264993  0.556760  0.264728 -0.770968  ...  1.254689 -0.082752  0.416986
# 185295 -0.078571 -0.958382  0.029454  ... -0.623486  0.306452 -0.310439
# 171218  0.244503  0.197289 -0.922308  ... -0.342613 -0.008275 -0.352955
# 266896 -0.051345  0.283180 -0.205530  ... -0.809064  0.361868  0.598916
# 188112  0.865317  0.502708  0.910594  ...  0.286499 -0.370368 -0.081377
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# Class
# 0      0.035164  0.004478  0.045698 -0.058384  0.107112  0.078286 -0.088700
# 1     -4.771948  3.623778 -7.033281  4.542029 -3.151225 -1.397737 -5.568731
#
#              V8        V9       V10  ...       V21       V22       V23  \
# Class                                ...
# 0     -0.080821 -0.047318  0.013459  ... -0.032688 -0.049296  0.011781
# 1      0.570636 -2.581123 -5.676883  ...  0.713588  0.014049 -0.040308
#
#             V24       V25       V26       V27       V28      Amount  Time_Hour
# Class
# 0     -0.011407  0.007623 -0.041055 -0.042232 -0.015654   70.806789  14.095528
# 1     -0.105130  0.041449  0.051648  0.170575  0.075667  122.211321  11.646341
#
# [2 rows x 30 columns]

# %% [markdown]
# # Splitting data into features & target

# %%
X=new_dataset.drop(columns='Class',axis=1)
Y=new_dataset['Class']

# %%
print(X)
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 264993 -0.412665  0.799263  0.211213  0.337211  0.298819  0.194876  0.173101
# 185295 -1.901385 -1.641704  1.801183 -0.380705  0.753314 -0.819420  0.318177
# 171218 -0.315761  0.479915  0.779429 -1.140265  0.901688  0.639046  0.475414
# 266896  2.012053  0.076522 -1.616732  0.339402  0.381926 -0.583722  0.042644
# 188112 -1.905378  0.767421  2.512406  0.507226 -1.797051  1.187800 -1.236078
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 280143  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 280149 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 281144 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 281674  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
# ...

# %%
print(Y)
# Out:
# 264993    0
# 185295    0
# 171218    0
# 266896    0
# 188112    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression  # Corrected import
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
logR=LogisticRegression()

# %%
logR.fit(X_train,Y_train)
# Out:
# C:\Users\rohan\anaconda4\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_pred=logR.predict(X_test)

# %%
accuracy_score(Y_test,X_train_pred)
# Out:
# 0.934010152284264

# %%
print('Accuracy of test data:',data_accuracy)
# Out:
# Accuracy of test data: 0.934010152284264

# %%
print('Accuracy:',data_accuracy)
# Out:
# Accuracy: 0.934010152284264

# %%
precision_score(Y_test,X_train_pred)
# Out:
# 0.967032967032967

# %%
f1_score(Y_test,X_train_pred)
# Out:
# 0.9312169312169313

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(X_test)
accuracy_score(Y_test,y_pred)
# Out:
# 0.9035532994923858

# %%
precision_score(Y_test,y_pred)
# Out:
# 0.898989898989899

# %%
f1_score(Y_test,y_pred)
# Out:
# 0.9035532994923858

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf=rf.predict(X_test)

# %%
accuracy_score(Y_test,y_pred_rf)
# Out:
# 0.9238578680203046

# %%
precision_score(Y_test,y_pred_rf)
# Out:
# 0.9882352941176471

# %%
f1_score(Y_test,y_pred_rf)
# Out:
# 0.9180327868852458

# %%
# using logestic regression we get higher accuracy and f1 score
